# %%
import pandas as pd
import numpy as np

data=pd.read_csv("arrests.csv")
data.head()
# Out:
#         PK       CCR   AGE GENDER RACE           ARRESTTIME  \
# 0  1975272  16158872  42.0      F    B  2016-08-24T12:20:00
# 1  1974456  16144120  31.0      M    W  2016-08-03T14:55:00
# 2  1974466  16144165  63.0      F    B  2016-08-03T16:45:00
# 3  1974550  16145257  25.0      F    W  2016-08-05T02:36:00
# 4  1974596  16145962  25.0      M    B  2016-08-06T02:00:00
#
#                                      ARRESTLOCATION  \
# 0         4700 Block Centre AV Pittsburgh, PA 15213
# 1  4200 Block Steubenville PKE Pittsburgh, PA 15205
# 2        900 Block Freeport RD Fox Chapel, PA 15238
# 3       Foreland ST & Cedar AV Pittsburgh, PA 15212
# 4         900 Block Woodlow ST Pittsburgh, PA 15205
#
#                                             OFFENSES  \
# 0                                 3929 Retail Theft.
# 1       13(a)(16) Possession of Controlled Substance
# 2                                 3929 Retail Theft.
# 3  5503 Disorderly Conduct. / 5505 Public Drunken...
# ...

# %%
#Sorted arrest data by neighborhood
data1=data['INCIDENTNEIGHBORHOOD'].value_counts()
#Showing bottom 30 neighborhoods which have the least arrest data
data1.tail(30)
# Out:
# Upper Lawrenceville            138
# Morningside                    137
# Lincoln Place                  129
# Duquesne Heights               128
# Friendship                     122
# Esplen                         121
# Polish Hill                    114
# Arlington Heights              109
# Mount Oliver                    96
# Glen Hazel                      91
# Allegheny West                  86
# Golden Triangle/Civic Arena     83
# Windgap                         76
# Hays                            75
# Fairywood                       74
# Summer Hill                     58
# Oakwood                         54
# Outside State                   45
# Outside County                  41
# East Carnegie                   36
# St. Clair                       35
# Chartiers City                  28
# Swisshelm Park                  27
# New Homestead                   26
# Ridgemont                       25
# Central Northside               23
# Regent Square                   22
# ...

# %%
data1.head(30)
# Out:
# Central Business District    2729
# South Side Flats             2315
# Carrick                      1623
# East Allegheny               1518
# Homewood South               1460
# Homewood North               1311
# East Liberty                 1218
# Marshall-Shadeland           1039
# Bluff                         995
# Mount Washington              976
# Knoxville                     925
# Hazelwood                     875
# Lincoln-Lemington-Belmar      867
# Brookline                     865
# Beechview                     844
# Sheraden                      833
# Allegheny Center              831
# Perry South                   761
# Brighton Heights              758
# East Hills                    736
# Shadyside                     688
# Bloomfield                    681
# Middle Hill                   670
# Allentown                     662
# Fineview                      623
# Central North Side            622
# Crawford-Roberts              574
# ...

# %% [markdown]
# ### My Conclusion
#
# According to my dataset, the neighborhood that had the fewest arrests is Mt. Oliver. This result really surprises me as I have lived in Pittsburgh my whole life and never thought of Mt. Oliver as a particularly nice neighborhood. As for our group pick, St. Clair ranked number ten for least arrests with a total of thirty five. This is still a very respectable position in the list as the worst two areas in the dataset (Central Business District and South Side Flats) have over two thousand arrests each. As for how I arrived at my results, I did not take severity of crime into account because all of the offenses were fairly severe or at the very least severe enough to get arrested for. Given this, I simply sorted the dataset by how many times a neighborhood appeared.
